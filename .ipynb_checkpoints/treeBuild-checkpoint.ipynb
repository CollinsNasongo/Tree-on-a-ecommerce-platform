# %%
import requests
from bs4 import BeautifulSoup

# %%
class WebPage:
    def __init__(self, url):
        self.url = url
    def view_page(self):
        source = requests.get(self.url)
        soup = BeautifulSoup(source.content, 'lxml')
        soup = soup.prettify()
        return print(soup)

# %%
jumia = WebPage("https://www.jumia.co.ke/")

# %%
jumia.view_page()
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Jumia Kenya | Online Shopping for Groceries, Appliances, Cleaning Supplies &amp; more
#   </title>
#   <meta content="product" property="og:type"/>
#   <meta content="Jumia Kenya" property="og:site_name"/>
#   <meta content="Jumia Kenya | Online Shopping for Groceries, Appliances, Cleaning Supplies &amp; more" property="og:title"/>
#   <meta content="Jumia Kenya the #1 Online store in Kenya ✓ Buy Phones, Electronics, Appliances, Groceries, Cleaning Supplies, Home Essentials from top brands ✓ Best prices in Kenya ✓ Online shop you can trust ✓ Order now and enjoy pay on delivery! " property="og:description"/>
#   <meta content="/" property="og:url"/>
#   <meta content="https://ke.jumia.is/cms/icons/jumialogo-x-4.png" property="og:image"/>
#   <meta content="en_KE" property="og:locale"/>
#   <meta content="Jumia Kenya | Online Shopping for Groceries, Appliances, Cleaning Supplies &amp; more" name="title"/>
#   <meta content="index, follow" name="robots"/>
#   <meta content="Jumia Kenya the #1 Online store in Kenya ✓ Buy Phones, Electronics, Appliances, Groceries, Cleaning Supplies, Home Essentials from top brands ✓ Best prices in Kenya ✓ Online shop you can trust ✓ Order now and enjoy pay on delivery! " name="description"/>
#   <link href="android-app://com.jumia.android/JUMIA/KE?utm_source=google&amp;utm_medium=organic&amp;adjust_tracker=j1hd8h&amp;adjust_campaign=GOOGLE_SEARCH&amp;adjust_adgroup=https%3A%2F%2Fwww.jumia.co.ke%2F" rel="alternate"/>
#   <link href="https://www.jumia.co.ke/" rel="canonical"/>
#   <link href="https://www.jumia.com.eg/" hreflang="en-eg" rel="alternate"/>
#   <link href="https://www.jumia.com.eg/ar/" hreflang="ar" rel="alternate"/>
#   <link href="https://www.jumia.ma/" hreflang="fr" rel="alternate"/>
#   <link href="https://www.jumia.ma/ar/" hreflang="ar-ma" rel="alternate"/>
#   <link href="https://www.jumia.dz/ar/" hreflang="ar-dz" rel="alternate"/>
#   <link href="https://www.jumia.co.ke/" hreflang="en-ke" rel="alternate"/>
#   <link href="https://www.jumia.ci/" hreflang="fr-ci" rel="alternate"/>
#   <link href="https://www.jumia.com.gh/" hreflang="en-gh" rel="alternate"/>
#   <link href="https://www.jumia.sn/" hreflang="fr-sn" rel="alternate"/>
#   <link href="https://www.jumia.dz/" hreflang="fr-dz" rel="alternate"/>
#   <link href="https://www.jumia.com.tn/" hreflang="fr-tn" rel="alternate"/>
#   <link href="https://www.jumia.ug/" hreflang="en-ug" rel="alternate"/>
#   <link href="https://www.jumia.com.ng/" hreflang="en" rel="alternate"/>
#   <meta content="2099414773624117" property="fb:app_id"/>
#   <meta content="395103207248808" property="fb:pages"/>
#   <meta content="n_VPq2qj81eefHQXQuWUQcpCjf22dILtzJ-5fqwv3cY" name="google-site-verification"/>
#   <meta content="18D4C7784A54CEB370A0B89D0634A096" name="msvalidate.01"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <link href="https://www.jumia.co.ke/assets_he/css/main.4ae4174a.css" rel="stylesheet"/>
#   <link href="https://www.jumia.co.ke/assets_he/favicon.87f00114.ico" rel="icon" sizes="any" type="image/ico"/>
#   <link href="https://www.jumia.co.ke/assets_he/favicon.adbd556a.svg" rel="icon" type="image/svg+xml"/>
#   <link href="//bam.nr-data.net" rel="preconnect dns-prefetch"/>
#   <link href="//js-agent.newrelic.com" rel="preconnect dns-prefetch"/>
#   <link href="//www.google-analytics.com" rel="preconnect dns-prefetch"/>
#   <link href="//www.googletagmanager.com" rel="preconnect dns-prefetch"/>
#   <link href="//www.facebook.com" rel="preconnect dns-prefetch"/>
#   <link href="//connect.facebook.net" rel="preconnect dns-prefetch"/>
#   <link href="//static.criteo.net" rel="preconnect dns-prefetch"/>
#   <link href="//sslwidget.criteo.com" rel="preconnect dns-prefetch"/>
#   <link href="//dis.eu.criteo.com" rel="preconnect dns-prefetch"/>
#   <link href="//creativecdn.com" rel="preconnect dns-prefetch"/>
#   <link href="https://ke.jumia.is" rel="dns-prefetch"/>
#  </head>
#  <body>
#   <script type="text/javascript">
#    window.NREUM||(NREUM={});NREUM.info = {"agent":"","beacon":"bam.nr-data.net","errorBeacon":"bam.nr-data.net","licenseKey":"b76de0635f","applicationID":"200156797","applicationTime":17.858264,"transactionName":"NVxXYhMHChFYVUELDQwWdkMSEgsPFn5aDwdCRRVmLjUw","queueTime":0,"ttGuid":"19872a83f192eb91","agentToken":null}; (window.NREUM||(NREUM={})).init={ajax:{deny_list:["bam.nr-data.net"]}};(window.NREUM||(NREUM={})).loader_config={licenseKey:"b76de0635f",applicationID:"200156797"};window.NREUM||(NREUM={}),__nr_require=function(t,e,n){function r(n){if(!e[n]){var i=e[n]={exports:{}};t[n][0].call(i.exports,function(e){var i=t[n][1][e];return r(i||e)},i,i.exports)}return e[n].exports}if("function"==typeof __nr_require)return __nr_require;for(var i=0;i<n.length;i++)r(n[i]);return r}({1:[function(t,e,n){function r(){}function i(t,e,n,r){return function(){return s.recordSupportability("API/"+e+"/called"),o(t+e,[u.now()].concat(c(arguments)),n?null:this,r),n?void 0:this}}var o=t("handle"),a=t(9),c=t(10),f=t("ee").get("tracer"),u=t("loader"),s=t(4),d=NREUM;"undefined"==typeof window.newrelic&&(newrelic=d);var p=["setPageViewName","setCustomAttribute","setErrorHandler","finished","addToTrace","inlineHit","addRelease"],l="api-",v=l+"ixn-";a(p,function(t,e){d[e]=i(l,e,!0,"api")}),d.addPageAction=i(l,"addPageAction",!0),d.setCurrentRouteName=i(l,"routeName",!0),e.exports=newrelic,d.interaction=function(){return(new r).get()};var m=r.prototype={createTracer:function(t,e){var n={},r=this,i="function"==typeof e;return o(v+"tracer",[u.now(),t,n],r),function(){if(f.emit((i?"":"no-")+"fn-start",[u.now(),r,i],n),i)try{return e.apply(this,arguments)}catch(t){throw f.emit("fn-err",[arguments,this,t],n),t}finally{f.emit("fn-end",[u.now()],n)}}}};a("actionText,setName,setAttribute,save,ignore,onEnd,getContext,end,get".split(","),function(t,e){m[e]=i(v,e)}),newrelic.noticeError=function(t,e){"string"==typeof t&&(t=new Error(t)),s.recordSupportability("API/noticeError/called"),o("err",[t,u.now(),!1,e])}},{}],2:[function(t,e,n){function r(t){if(NREUM.init){for(var e=NREUM.init,n=t.split("."),r=0;r<n.length-1;r++)if(e=e[n[r]],"object"!=typeof e)return;return e=e[n[n.length-1]]}}e.exports={getConfiguration:r}},{}],3:[function(t,e,n){var r=!1;try{var i=Object.defineProperty({},"passive",{get:function(){r=!0}});window.addEventListener("testPassive",null,i),window.removeEventListener("testPassive",null,i)}catch(o){}e.exports=function(t){return r?{passive:!0,capture:!!t}:!!t}},{}],4:[function(t,e,n){function r(t,e){var n=[a,t,{name:t},e];return o("storeMetric",n,null,"api"),n}function i(t,e){var n=[c,t,{name:t},e];return o("storeEventMetrics",n,null,"api"),n}var o=t("handle"),a="sm",c="cm";e.exports={constants:{SUPPORTABILITY_METRIC:a,CUSTOM_METRIC:c},recordSupportability:r,recordCustom:i}},{}],5:[function(t,e,n){function r(){return c.exists&&performance.now?Math.round(performance.now()):(o=Math.max((new Date).getTime(),o))-a}function i(){return o}var o=(new Date).getTime(),a=o,c=t(11);e.exports=r,e.exports.offset=a,e.exports.getLastTimestamp=i},{}],6:[function(t,e,n){function r(t,e){var n=t.getEntries();n.forEach(function(t){"first-paint"===t.name?l("timing",["fp",Math.floor(t.startTime)]):"first-contentful-paint"===t.name&&l("timing",["fcp",Math.floor(t.startTime)])})}function i(t,e){var n=t.getEntries();if(n.length>0){var r=n[n.length-1];if(u&&u<r.startTime)return;var i=[r],o=a({});o&&i.push(o),l("lcp",i)}}function o(t){t.getEntries().forEach(function(t){t.hadRecentInput||l("cls",[t])})}function a(t){var e=navigator.connection||navigator.mozConnection||navigator.webkitConnection;if(e)return e.type&&(t["net-type"]=e.type),e.effectiveType&&(t["net-etype"]=e.effectiveType),e.rtt&&(t["net-rtt"]=e.rtt),e.downlink&&(t["net-dlink"]=e.downlink),t}function c(t){if(t instanceof y&&!w){var e=Math.round(t.timeStamp),n={type:t.type};a(n),e<=v.now()?n.fid=v.now()-e:e>v.offset&&e<=Date.now()?(e-=v.offset,n.fid=v.now()-e):e=v.now(),w=!0,l("timing",["fi",e,n])}}function f(t ...
#   </script>
#   <div id="jm">
#    <div class="banner" data-bnrid="101" data-end="2023-08-31T11:42:00+03:00" style="background:#f9992d;">
#     <div class="row _no-go -phs">
#      <a class="col16 ar _1168-56" data-creative="https://ke.jumia.is/cms/2022/JA22/Live/Day01/Generics/J22_Sliderticky_Banner.gif" data-id="home_STB_JA22_GEN" data-name="STB_JA22_GEN" data-position="banner_top" data-track-onclick="eecPromo" data-track-onview="eecPromo" href="/mlp-anniversary/?source=STB_JA22_GEN">
#       <img alt="STB_JA22_GEN" class="_ni" data-lazy="" data-src="https://ke.jumia.is/cms/2022/JA22/Live/Day01/Generics/J22_Sliderticky_Banner.gif" src="..."/>
#      </a>
#     </div>
#    </div>
#    <div class="vb row -i-ctr -j-ctr _head -bg-gy05 -gy5">
#     <div class="col3 -df -j-start">
#      <a class="_link -df -i-ctr -or5 -m -fs12" href="https://www.jumia.co.ke/sp-market-place/" rel="noopener" target="_blank">
#       <svg class="ic -f-or5 -maxs" height="16" viewbox="0 0 24 24" width="16">
#        <use xlink:href="https://www.jumia.co.ke/assets_he/images/i-icons.edbc85eb.svg#cat-services">
#        </use>
#       </svg>
#       Sell on Jumia
#      </a>
#     </div>
#     <div class="col10 -df -j-ctr -fs0">
#      <a class="vent-link" href="https://food.jumia.co.ke/" rel="nofollow noopener" target="_blank" title="Jumia Food">
#       <svg class="ic" height="24" viewbox="0 0 66 24" width="66">
#        <use xlink:href="https://www.jumia.co.ke/assets_he/images/i-global.cd8c5f0c.svg#venture-food">
#        </use>
#       </svg>
#      </a>
#      <a class="vent-link" href="https://www.jumia.co.ke/mlp-jumia-prime/" rel="nofollow noopener" target="_blank" title="Jumia Prime">
#       <svg class="ic" height="24" viewbox="0 0 77 24" width="77">
#        <use xlink:href="https://www.jumia.co.ke/assets_he/images/i-global.cd8c5f0c.svg#venture-prime">
#        </use>
#       </svg>
#      </a>
#      <a class="vent-link" href="https://food.jumia.co.ke/drinks/k0zt/jumia-party" rel="nofollow noopener" target="_blank" title="Jumia Party">
#      </a>
#      <a class="vent-link" href="https://pay.jumia.co.ke/?utm_source=jumia&amp;utm_medium=mall&amp;utm_campaign=Venturebar" rel="nofollow noopener" target="_blank" title="Jumia Pay">
#       <svg class="ic" height="24" viewbox="0 0 60 24" width="60">
#        <use xlink:href="https://www.jumia.co.ke/assets_he/images/i-global.cd8c5f0c.svg#venture-pay">
#        </use>
#       </svg>
#      </a>
#      <a class="vent-link" href="https://www.jumia.co.ke/sp-jumia-logistics/?utm_source=jumia&amp;utm_medium=mall&amp;utm_campaign=Venturebar" rel="nofollow noopener" target="_blank" title="Jumia Logistic Services">
#       <svg class="ic" height="24" viewbox="0 0 108 24" width="108">
#        <use xlink:href="https://www.jumia.co.ke/assets_he/images/i-global.cd8c5f0c.svg#venture-logistics">
#        </use>
#       </svg>
#      </a>
#     </div>
#     <div class="col3 -df -j-end -wt -mla -gy5">
#     </div>
#    </div>
#    <header class="header">
#     <section class="row -i-ctr -fw-nw -pvm">
#      <div class="col3 -df -i-ctr">
#       <a class="-df -i-ctr -mra" href="/">
#        <svg aria-label="Jumia Kenya - Online Shopping for TVs, Electronics, Phones, Fashion &amp; more" class="ic" height="30" role="img" viewbox="0 0 172 30" width="134">
#         <use xlink:href="https://www.jumia.co.ke/assets_he/images/i-shop-jumia.85ab1fc3.svg#logo">
#         </use>
#        </svg>
#       </a>
#      </div>
#      <form action="/catalog/" class="cola -df" data-track-onsubmit="search" id="search" method="get">
#       <div class="find">
#        <svg class="ic" height="24" viewbox="0 0 24 24" width="24">
#         <use xlink:href="https://www.jumia.co.ke/assets_he/images/i-icons.edbc85eb.svg#search">
#         </use>
#        </svg>
#        <input aria-label="Search" autocomplete="off" id="fi-q" name="q" placeholder="Search products, brands and categories" required="" type="text" value=""/>
#        <button aria-label="Reset" class="rst" type="button">
#         <svg class="ic" height="24" viewbox="0 0 24 24" width="24">
#          <use xlink:href="https://www.jumia.co.ke/assets_he/images/i-icons.edbc85eb.svg#close">
#          </use>
#         </svg>
#        </button>
#        <div class="sug">
#        </div>
#       </div>
#       <button class="btn _prim _md -mls -fsh0">
#        Search
#       </button>
#      </form>
#      <div class="col -df -j-bet -m -phn -i-ctr">
#       <div class="dpdw _pcent">
#        <input aria-controls="dpdw-login-box" aria-haspopup="true" aria-label="Account" class="tgl" id="dpdw-login" role="button" type="checkbox"/>
#        <label class="trig -df -i-ctr -fs16" for="dpdw-login">
#         <span class="-fsh0 -mrs">
#          <svg class="ic" height="24" viewbox="0 0 24 24" width="24">
#           <use xlink:href="https://www.jumia.co.ke/assets_he/images/i-icons.edbc85eb.svg#person">
#           </use>
#          </svg>
#         </span>
#         Account
#         <svg class="ic -mls -fsh0" height="18" viewbox="0 0 24 24" width="18">
#          <use xlink:href="https://www.jumia.co.ke/assets_he/images/i-icons.edbc85eb.svg#arrow-down">
#          </use>
#         </svg>
#        </label>
#        <div aria-labelledby="dpdw-login" class="box -r" id="dpdw-login-box" role="menu">
#         <div class="inbox">
#          <div class="-pam -hr-bb">
#           <a class="btn _prim -fw _md" href="/customer/account/login/?return=%2F">
#            Sign In
#           </a>
#          </div>
#          <a class="-df -i-ctr -pas -hov-bg-gy05 -hov-m" href="/customer/account/index/">
#           <svg class="ic -mrm -fsh0" height="24" viewbox="0 0 24 24" width="24">
#            <use xlink:href="https://www.jumia.co.ke/assets_he/images/i-icons.edbc85eb.svg#person">
#            </use>
#           </svg>
#           My Account
#          </a>
#          <a class="-df -i-ctr -pas -hov-bg-gy05 -hov-m" href="/customer/order/index/">
#           <svg class="ic -mrm -fsh0" height="24" viewbox="0 0 24 24" width="24">
#            <use xlink:href="https://www.jumia.co.ke/assets_he/images/i-icons.edbc85eb.svg#orders">
#            </use>
#           </svg>
#           Orders
#          </a>
#          <a class="-df -i-ctr -pas -hov-bg-gy05 -hov-m" href="/customer/wishlist/index/">
#           <svg class="ic -mrm -fsh0" height="24" viewbox="0 0 24 24" width="24">
#            <use xlink:href="https://www.jumia.co.ke/assets_he/images/i-icons.edbc85eb.svg#favorite-border">
#            </use>
#           </svg>
#           Saved Items
#          </a>
#         </div>
#        </div>
#       </div>
#       <div class="dpdw _pcent">
#        <input aria-controls="dpdw-help-box" aria-haspopup="true" aria-label="Help" class="tgl" id="dpdw-help" role="button" type="checkbox"/>
#        <label class="trig -df -i-ctr -fs16" for="dpdw-help">
#         <span class="-fsh0 -mrs">
#          <svg class="ic" height="24" viewbox="0 0 24 24" width="24">
#           <use xlink:href="https://www.jumia.co.ke/assets_he/images/i-icons.edbc85eb.svg#help-outline">
#           </use>
#          </svg>
#         </span>
#         Help
#         <svg class="ic -mls -fsh0" height="18" viewbox="0 0 24 24" width="18">
#          <use xlink:href="https://www.jumia.co.ke/assets_he/images/i-icons.edbc85eb.svg#arrow-down">
#          </use>
#         </svg>
#        </label>
#        <div aria-labelledby="dpdw-help" class="box -r" id="dpdw-help-box" role="menu">
#         <div class="inbox">
#          <a class="-df -i-ctr -phm -pv12 -hov-bg-gy05 -hov-m" href="https://www.jumia.co.ke/sp-help/">
#           Help Center
#          </a>
#          <a class="-df -i-ctr -phm -pv12 -hov-bg-gy05 -hov-m" href="https://www.jumia.co.ke/sp-place-track-order/">
#           Place &amp; Track Order
#          </a>
#          <a class="-df -i-ctr -phm -pv12 -hov-bg-gy05 -hov-m" href="https://www.jumia.co.ke/sp-cancel-order/">
#           Order Cancellation
#          </a>
#          <a class="-df -i-ctr -phm -pv12 -hov-bg-gy05 -hov-m" href="https://www.jumia.co.ke/sp-returns-refunds/">
#           Returns &amp; Refunds
#          </a>
#          <a class="-df -i-ctr -phm -pv12 -hov-bg-gy05 -hov-m" href="https://www.jumia.co.ke/sp-how-to-pay/">
#           Payment &amp; Jumia Account
#          </a>
#          <a class="-df -i-ctr -phm -pv12 -hov-bg-gy05 -hov-m" href="https://www.jumia.co.ke/sp-contact/">
#           Contact us
#          </a>
#          <div class="-tac -hr _hx2 -fs0 -pam">
#           <button class="btn _prim _md _i -fw" data-btn-lc="" data-eventaction="open" data-eventcategory="LiveChat" data-track-onclick="">
#            <svg class="ic" height="24" viewbox="0 0 24 24" width="24">
#             <use xlink:href="https://www.jumia.co.ke/assets_he/images/i-icons.edbc85eb.svg#chat">
#             </use>
#            </svg>
#            <span>
#             Live Chat
#            </span>
#           </button>
#          </div>
#         </div>
#        </div>
#       </div>
#       <a class="-df -i-ctr -gy8 -hov-or5 -phs -fs16" href="/cart/">
#        <span class="-mrs -fs0" id="ci">
#         <svg class="ic" height="24" viewbox="0 0 24 24" width="24">
#          <use xlink:href="https://www.jumia.co.ke/assets_he/images/i-icons.edbc85eb.svg#shopping-cart">
#          </use>
#         </svg>
#        </span>
#        Cart
#       </a>
#      </div>
#     </section>
#    </header>
#    <article class="banner _pp" data-ppb-rev="v1.0">
#     <div class="ctt-w">
#      <p class="ctt">
#       This website uses cookies. For further information on how we use cookies you can read our
#       <a class="_more -fs12" href="/sp-privacy/" rel="noopener" target="_blank">
#        Privacy and Cookie notice
#       </a>
#      </p>
#      <button aria-label="Close" class="cls">
#       <span class="ic-bg -bg-wt">
#        <svg class="ic -maxs" height="16" viewbox="0 0 24 24" width="16">
#         <use xlink:href="https://www.jumia.co.ke/assets_he/images/i-icons.edbc85eb.svg#close">
#         </use>
#        </svg>
#       </span>
#      </button>
#     </div>
#    </article>
#    <main class="has-b2top">
#     <style>
#      @media(min-width:1200px){main{background:center 0 no-repeat url('https://ke.jumia.is/cms/2022/JA22/Live/Day3/KE_JA22_Live_0622_Takeover.jpg');}}main{background-color:#6ac0d7;}
#     </style>
#     <div class="row -pvm">
#      <div class="col16 -df -j-bet -pbs">
#       <div class="flyout-w -fsh0 -fs0">
#        <div class="flyout" role="menu">
#         <a class="itm" href="https://www.jumia.co.ke/groceries/" role="menuitem">
#          <svg class="ic -mrxs -fsh0" height="20" viewbox="0 0 24 24" width="20">
#           <use xlink:href="https://www.jumia.co.ke/assets_he/images/i-icons.edbc85eb.svg#cat-groceries">
#           </use>
#          </svg>
#          <span class="text">
#           Supermarket
#          </span>
#         </a>
#         <a class="itm" href="/health-beauty/" role="menuitem">
#          <svg class="ic -mrxs -fsh0" height="20" viewbox="0 0 24 24" width="20">
#           <use xlink:href="https://www.jumia.co.ke/assets_he/images/i-icons.edbc85eb.svg#cat-beauty">
#           </use>
#          </svg>
#          <span class="text">
#           Health &amp; Beauty
#          </span>
#         </a>
#         <a class="itm" href="/home-office/" role="menuitem">
#          <svg class="ic -mrxs -fsh0" height="20" viewbox="0 0 24 24" width="20">
#           <use xlink:href="https://www.jumia.co.ke/assets_he/images/i-icons.edbc85eb.svg#cat-appliance">
#           </use>
#          </svg>
#          <span class="text">
#           Home &amp; Office
#          </span>
#         </a>
#         <a class="itm" href="/phones-tablets/" role="menuitem">
#          <svg class="ic -mrxs -fsh0" height="20" viewbox="0 0 24 24" width="20">
#           <use xlink:href="https://www.jumia.co.ke/assets_he/images/i-icons.edbc85eb.svg#cat-mobile">
#           </use>
#          </svg>
#          <span class="text">
#           Phones &amp; Tablets
#          </span>
#         </a>
#         <a class="itm" href="/computing/" role="menuitem">
#          <svg class="ic -mrxs -fsh0" height="20" viewbox="0 0 24 24" width="20">
#           <use xlink:href="https://www.jumia.co.ke/assets_he/images/i-icons.edbc85eb.svg#cat-computing">
#           </use>
#          </svg>
#          <span class="text">
#           Computing
#          </span>
#         </a>
#         <a class="itm" href="/electronics/" role="menuitem">
#          <svg class="ic -mrxs -fsh0" height="20" viewbox="0 0 24 24" width="20">
#           <use xlink:href="https://www.jumia.co.ke/assets_he/images/i-icons.edbc85eb.svg#cat-tv">
#           </use>
#          </svg>
#          <span class="text">
#           Electronics
#          </span>
#         </a>
#         <a class="itm" href="/category-fashion-by-jumia/" role="menuitem">
#          <svg class="ic -mrxs -fsh0" height="20" viewbox="0 0 24 24" width="20">
#           <use xlink:href="https://www.jumia.co.ke/assets_he/images/i-icons.edbc85eb.svg#cat-fashion">
#           </use>
#          </svg>
#          <span class="text">
#           Fashion
#          </span>
#         </a>
#         <a class="itm" href="/video-games/" role="menuitem">
#          <svg class="ic -mrxs -fsh0" height="20" viewbox="0 0 24 24" width="20">
#           <use xlink:href="https://www.jumia.co.ke/assets_he/images/i-icons.edbc85eb.svg#cat-games">
#           </use>
#          </svg>
#          <span class="text">
#           Gaming
#          </span>
#         </a>
#         <a class="itm" href="/baby-products/" role="menuitem">
#          <svg class="ic -mrxs -fsh0" height="20" viewbox="0 0 24 24" width="20">
#           <use xlink:href="https://www.jumia.co.ke/assets_he/images/i-icons.edbc85eb.svg#cat-baby">
#           </use>
#          </svg>
#          <span class="text">
#           Baby Products
#          </span>
#         </a>
#         <a class="itm" href="/sporting-goods/" role="menuitem">
#          <svg class="ic -mrxs -fsh0" height="20" viewbox="0 0 24 24" width="20">
#           <use xlink:href="https://www.jumia.co.ke/assets_he/images/i-icons.edbc85eb.svg#cat-fitness">
#           </use>
#          </svg>
#          <span class="text">
#           Sporting Goods
#          </span>
#         </a>
#         <a class="itm" href="/patio-lawn-garden/" role="menuitem">
#          <svg class="ic -mrxs -fsh0" height="20" viewbox="0 0 24 24" width="20">
#           <use xlink:href="https://www.jumia.co.ke/assets_he/images/i-icons.edbc85eb.svg#cat-garden">
#           </use>
#          </svg>
#          <span class="text">
#           Garden &amp; Outdoors
#          </span>
#         </a>
#         <a class="itm" role="menuitem" tabindex="0">
#          <svg class="ic -mrxs -fsh0" height="20" viewbox="0 0 24 24" width="20">
#           <use xlink:href="https://www.jumia.co.ke/assets_he/images/i-icons.edbc85eb.svg#cat-othercategories">
#           </use>
#          </svg>
#          <span class="text">
#           Other categories
#          </span>
#         </a>
#        </div>
#       </div>
#       <div class="sldr _img _main -rad4 -oh -fsh0 -mhm" data-track-onsliderview="eecPromo" id="sl-topblock">
#        <input checked="" class="sld" id="sl-topblock-sld-1" name="sl-topblock-sld" type="radio"/>
#        <a class="itm" data-creative="https://ke.jumia.is/cms/2022/JA22/Live/HP/Day05/SuperSavers/KE_JA22_WKNDPlan_0622_S.jpg" data-id="home_SX_JA22_UND_SuperSavers" data-name="SX_JA22_UND_SuperSavers" data-position="slider_1_1" data-track-onclick="eecPromo" href="https://www.jumia.co.ke/mlp-super-savers/">
#         <img alt="Super Savers" class="-fw" data-lazy-slide="" data-src="https://ke.jumia.is/cms/2022/JA22/Live/HP/Day05/SuperSavers/KE_JA22_WKNDPlan_0622_S.jpg" src="..."/>
#        </a>
#        <label aria-label="Go to slide 7" class="lab" for="sl-topblock-sld-7">
#        </label>
#        <label aria-label="Go to slide 1" class="dot" for="sl-topblock-sld-1">
#        </label>
#        <input class="sld" id="sl-topblock-sld-2" name="sl-topblock-sld" type="radio"/>
#        <a class="itm" data-creative="https://ke.jumia.is/cms/2022/JA22/Live/Day01/Generics/KE_JA22_FS_Live_0622_S.jpg" data-id="home_SX_JA22_FLS_GEN" data-name="SX_JA22_FLS_GEN" data-position="slider_1_2" data-track-onclick="eecPromo" href="https://www.jumia.co.ke/flash-sales/">
#         <img alt="Flash Sales" class="-fw" data-lazy-slide="" data-src="https://ke.jumia.is/cms/2022/JA22/Live/Day01/Generics/KE_JA22_FS_Live_0622_S.jpg" src="..."/>
#        </a>
#        <label aria-label="Go to slide 1" class="lab" for="sl-topblock-sld-1">
#        </label>
#        <label aria-label="Go to slide 2" class="dot" for="sl-topblock-sld-2">
#        </label>
#        <input class="sld" id="sl-topblock-sld-3" name="sl-topblock-sld" type="radio"/>
#        <a class="itm" data-creative="https://ke.jumia.is/cms/2022/JA22/Live/Day01/Sliders/Slider-GIF_V2.gif" data-id="home_SX_JA22_GEN" data-name="SX_JA22_GEN" data-position="slider_1_3" data-track-onclick="eecPromo" href="https://www.jumia.co.ke/mlp-anniversary/">
#         <img alt="JA22" class="-fw" data-lazy-slide="" data-src="https://ke.jumia.is/cms/2022/JA22/Live/Day01/Sliders/Slider-GIF_V2.gif" src="..."/>
#        </a>
#        <label aria-label="Go to slide 2" class="lab" for="sl-topblock-sld-2">
#        </label>
#        <label aria-label="Go to slide 3" class="dot" for="sl-topblock-sld-3">
#        </label>
#        <input class="sld" id="sl-topblock-sld-4" name="sl-topblock-sld" type="radio"/>
#        <a class="itm" data-creative="https://ke.jumia.is/cms/2022/JA22/Live/Day01/Sliders/KE_JA22_Phones_Live_ACD_0622_S.jpg" data-id="home_SX_JA22_ACD_UND_Phones" data-name="SX_JA22_ACD_UND_Phones" data-position="slider_1_4" data-track-onclick="eecPromo" href="https://www.jumia.co.ke/phones-tablets/">
#         <img alt="Phones" class="-fw" data-lazy-slide="" data-src="https://ke.jumia.is/cms/2022/JA22/Live/Day01/Sliders/KE_JA22_Phones_Live_ACD_0622_S.jpg" src="..."/>
#        </a>
#        <label aria-label="Go to slide 3" class="lab" for="sl-topblock-sld-3">
#        </label>
#        <label aria-label="Go to slide 4" class="dot" for="sl-topblock-sld-4">
#        </label>
#        <input class="sld" id="sl-topblock-sld-5" name="sl-topblock-sld" type="radio"/>
#        <a class="itm" data-creative="https://ke.jumia.is/cms/2022/JA22/Live/HP/Day03/Sliders/KE_JA22_Baby_0622_S.jpg" data-id="home_SX_JA22_ACD_UND_BabyProd" data-name="SX_JA22_ACD_UND_BabyProd" data-position="slider_1_5" data-track-onclick="eecPromo" href="https://www.jumia.co.ke/baby-products/">
#         <img alt="Baby Products" class="-fw" data-lazy-slide="" data-src="https://ke.jumia.is/cms/2022/JA22/Live/HP/Day03/Sliders/KE_JA22_Baby_0622_S.jpg" src="..."/>
#        </a>
#        <label aria-label="Go to slide 4" class="lab" for="sl-topblock-sld-4">
#        </label>
#        <label aria-label="Go to slide 5" class="dot" for="sl-topblock-sld-5">
#        </label>
#        <input class="sld" id="sl-topblock-sld-6" name="sl-topblock-sld" type="radio"/>
#        <a class="itm" data-creative="https://ke.jumia.is/cms/2022/JA22/Live/Food/_1424x768_S.jpg" data-id="home_SX_JA22_FOD_ACD_PizzaInn" data-name="SX_JA22_FOD_ACD_PizzaInn" data-position="slider_1_6" data-track-onclick="eecPromo" href="https://food.jumia.co.ke/" rel="noopener" target="_blank">
#         <img alt="Jumia Food" class="-fw" data-lazy-slide="" data-src="https://ke.jumia.is/cms/2022/JA22/Live/Food/_1424x768_S.jpg" src="..."/>
#        </a>
#        <label aria-label="Go to slide 5" class="lab" for="sl-topblock-sld-5">
#        </label>
#        <label aria-label="Go to slide 6" class="dot" for="sl-topblock-sld-6">
#        </label>
#        <input class="sld" id="sl-topblock-sld-7" name="sl-topblock-sld" type="radio"/>
#        <a class="itm" data-creative="https://ke.jumia.is/cms/2022/JA22/Live/HP/Pay/KE_JumiaPay__Survey_0523_S.jpg" data-id="home_SX_PAY_Survey" data-name="SX_PAY_Survey" data-position="slider_1_7" data-track-onclick="eecPromo" href="https://pay.jumia.co.ke/JumiaPay_Survey" rel="noopener" target="_blank">
#         <img alt="Pay Survey" class="-fw" data-lazy-slide="" data-src="https://ke.jumia.is/cms/2022/JA22/Live/HP/Pay/KE_JumiaPay__Survey_0523_S.jpg" src="..."/>
#        </a>
#        <label aria-label="Go to slide 6" class="lab" for="sl-topblock-sld-6">
#        </label>
#        <label aria-label="Go to slide 7" class="dot" for="sl-topblock-sld-7">
#        </label>
#        <label aria-label="Go to slide 7" class="lab" for="sl-topblock-sld-7">
#        </label>
#        <label aria-label="Go to slide 1" class="lab" for="sl-topblock-sld-1">
#        </label>
#        <div class="left">
#         <svg class="ic -f-wt" height="24" viewbox="0 0 24 24" width="24">
#          <use xlink:href="https://www.jumia.co.ke/assets_he/images/i-icons.edbc85eb.svg#arrow-left">
#          </use>
#         </svg>
#        </div>
#        <div class="right">
#         <svg class="ic -f-wt" height="24" viewbox="0 0 24 24" width="24">
#          <use xlink:href="https://www.jumia.co.ke/assets_he/images/i-icons.edbc85eb.svg#arrow-right">
#          </use>
#         </svg>
#        </div>
#       </div>
#       <div class="-df -c-bet -fw-w -fg1 -m-dn -h-flyout -oh -fs0">
#        <div class="card -df -fw-w -c-spar -fg1 -phm -h-50p_-m -oh">
#         <a class="-df -i-ctr -oh -fw" data-creative="https://ke.jumia.is/cms/2021/W26/CP/new-hp-sliders/Webp.net-resizeimage-(1).png" data-id="home_HELP CENTER" data-name="HELP CENTER" data-position="topblock_top_1" data-track-onclick="eecPromo" data-track-onview="eecPromo" href="https://www.jumia.co.ke/sp-help/?source=HP_ICON">
#          <img alt="HELP CENTER" class="_ni -fsh0 -mrs" data-lazy="" data-src="https://ke.jumia.is/cms/2021/W26/CP/new-hp-sliders/Webp.net-resizeimage-(1).png" height="34" src="..." width="34"/>
#          <div class="-flupp -gy8 -oh">
#           <div class="-m -fs14 -elli">
#            HELP CENTER
#           </div>
#           <div class="-fs12 -elli">
#            Guide To Customer Care
#           </div>
#          </div>
#         </a>
#         <a class="-df -i-ctr -oh -fw" data-creative="https://ke.jumia.is/cms/2021/W26/CP/new-hp-sliders/icone-2-return.png" data-id="home_EASY RETURN" data-name="EASY RETURN" data-position="topblock_top_2" data-track-onclick="eecPromo" data-track-onview="eecPromo" href="https://www.jumia.co.ke/sp-returns-refunds/?source=HP_Icon">
#          <img alt="EASY RETURN" class="_ni -fsh0 -mrs" data-lazy="" data-src="https://ke.jumia.is/cms/2021/W26/CP/new-hp-sliders/icone-2-return.png" height="34" src="..." width="34"/>
#          <div class="-flupp -gy8 -oh">
#           <div class="-m -fs14 -elli">
#            EASY RETURN
#           </div>
#           <div class="-fs12 -elli">
#            Quick Refund
#           </div>
#          </div>
#         </a>
#         <a class="-df -i-ctr -oh -fw" data-creative="https://ke.jumia.is/cms/2021/W26/CP/new-hp-sliders/icone-2-payment.png" data-id="home_SELL ON JUMIA" data-name="SELL ON JUMIA" data-position="topblock_top_3" data-track-onclick="eecPromo" data-track-onview="eecPromo" href="https://www.jumia.co.ke/sp-market-place/?source=HP_Icon">
#          <img alt="SELL ON JUMIA" class="_ni -fsh0 -mrs" data-lazy="" data-src="https://ke.jumia.is/cms/2021/W26/CP/new-hp-sliders/icone-2-payment.png" height="34" src="..." width="34"/>
#          <div class="-flupp -gy8 -oh">
#           <div class="-m -fs14 -elli">
#            SELL ON JUMIA
#           </div>
#           <div class="-fs12 -elli">
#            Millions Of Visitors
#           </div>
#          </div>
#         </a>
#        </div>
#        <div class="-fw" data-creative="https://ke.jumia.is/cms/2022/JA22/Live/Day01/Generics/ezgif.com-gif-maker.gif" data-id="home_Jumia Prime" data-name="Jumia Prime" data-position="topblock_bottom" data-track-onclick="eecPromo" data-track-onview="eecPromo">
#         <a class="card ar _109-92 -oh -fs0 -h-50p_-m" href="https://www.jumia.co.ke/mlp-jumia-prime/">
#          <img alt="Jumia Prime" data-lazy="" data-src="https://ke.jumia.is/cms/2022/JA22/Live/Day01/Generics/ezgif.com-gif-maker.gif" src="..."/>
#         </a>
#        </div>
#       </div>
#      </div>
#      <div class="col16 -pvs">
#       <section class="card -oh _fw -rad4">
#        <div class="crs-w _main _thumb -fs0 _nav -tac _c-btn-on">
#         <div class="crs">
#          <div class="itm -pvs _v">
#           <a class="-fw -rad4 -hov-e-2" data-creative="https://ke.jumia.is/cms/2022/JA22/Live/Day01/Thumbnails/KE10yrs.png" data-id="home_DTN_JA22_GEN" data-name="DTN_JA22_GEN" data-position="thumbnails_1_1" data-track-onclick="eecPromo" data-track-onview="eecPromo" href="https://www.jumia.co.ke/mlp-anniversary/">
#            <div class="ar _1-1">
#             <img alt="All Deals" class="-rad4" data-lazy="" data-src="https://ke.jumia.is/cms/2022/JA22/Live/Day01/Thumbnails/KE10yrs.png" src="..."/>
#            </div>
#            <p class="-maxs -fs14 -elli2">
#             All Deals
#            </p>
#           </a>
#          </div>
#          <div class="itm -pvs _v">
#           <a class="-fw -rad4 -hov-e-2" data-creative="https://ke.jumia.is/cms/2022/JA22/Live/Day01/Thumbnails/Sale-Deals.png" data-id="home_DTN_JA22_CLS" data-name="DTN_JA22_CLS" data-position="thumbnails_1_2" data-track-onclick="eecPromo" data-track-onview="eecPromo" href="https://www.jumia.co.ke/mlp-super-savers/">
#            <div class="ar _1-1">
#             <img alt="Clearance Sale" class="-rad4" data-lazy="" data-src="https://ke.jumia.is/cms/2022/JA22/Live/Day01/Thumbnails/Sale-Deals.png" src="..."/>
#            </div>
#            <p class="-maxs -fs14 -elli2">
#             Clearance Sale
#            </p>
#           </a>
#          </div>
#          <div class="itm -pvs _v">
#           <a class="-fw -rad4 -hov-e-2" data-creative="https://ke.jumia.is/cms/2022/JA22/Live/Day01/Thumbnails/Jumia-Games.png" data-id="home_DTN_JA22_Games" data-name="DTN_JA22_Games" data-position="thumbnails_1_3" data-track-onclick="eecPromo" data-track-onview="eecPromo" href="https://www.jumia.co.ke/mlp-jumia-games/">
#            <div class="ar _1-1">
#             <img alt="Play &amp; Win" class="-rad4" data-lazy="" data-src="https://ke.jumia.is/cms/2022/JA22/Live/Day01/Thumbnails/Jumia-Games.png" src="..."/>
#            </div>
#            <p class="-maxs -fs14 -elli2">
#             Play &amp; Win
#            </p>
#           </a>
#          </div>
#          <div class="itm -pvs _v">
#           <a class="-fw -rad4 -hov-e-2" data-creative="https://ke.jumia.is/cms/2022/JA22/Live/Day01/Thumbnails/Supermarket-1.png" data-id="home_DTN_JA22_Grocery" data-name="DTN_JA22_Grocery" data-position="thumbnails_1_4" data-track-onclick="eecPromo" data-track-onview="eecPromo" href="https://www.jumia.co.ke/groceries/">
#            <div class="ar _1-1">
#             <img alt="Grocery" class="-rad4" data-lazy="" data-src="https://ke.jumia.is/cms/2022/JA22/Live/Day01/Thumbnails/Supermarket-1.png" src="..."/>
#            </div>
#            <p class="-maxs -fs14 -elli2">
#             Grocery
#            </p>
#           </a>
#          </div>
#          <div class="itm -pvs _v">
#           <a class="-fw -rad4 -hov-e-2" data-creative="https://ke.jumia.is/cms/2022/JA22/Live/Day01/Thumbnails/Home.png" data-id="home_DTN_JA22_KitchenDining" data-name="DTN_JA22_KitchenDining" data-position="thumbnails_1_5" data-track-onclick="eecPromo" data-track-onview="eecPromo" href="https://www.jumia.co.ke/home-kitchen-dining/">
#            <div class="ar _1-1">
#             <img alt="Kitchen &amp; Dining" class="-rad4" data-lazy="" data-src="https://ke.jumia.is/cms/2022/JA22/Live/Day01/Thumbnails/Home.png" src="..."/>
#            </div>
#            <p class="-maxs -fs14 -elli2">
#             Kitchen &amp; Dining
#            </p>
#           </a>
#          </div>
#          <div class="itm -pvs _v">
#           <a class="-fw -rad4 -hov-e-2" data-creative="https://ke.jumia.is/cms/2022/JA22/Live/Day01/Thumbnails/Entertainment.png" data-id="home_DTN_JA22_Electronics" data-name="DTN_JA22_Electronics" data-position="thumbnails_1_6" data-track-onclick="eecPromo" data-track-onview="eecPromo" href="https://www.jumia.co.ke/electronics/">
#            <div class="ar _1-1">
#             <img alt="Electronics" class="-rad4" data-lazy="" data-src="https://ke.jumia.is/cms/2022/JA22/Live/Day01/Thumbnails/Entertainment.png" src="..."/>
#            </div>
#            <p class="-maxs -fs14 -elli2">
#             Electronics
#            </p>
#           </a>
#          </div>
#          <div class="itm -pvs _v">
#           <a class="-fw -rad4 -hov-e-2" data-creative="https://ke.jumia.is/cms/2022/JA22/Live/Day01/Thumbnails/Skin-Essentials.png" data-id="home_DTN_JA22_Beauty" data-name="DTN_JA22_Beauty" data-position="thumbnails_1_7" data-track-onclick="eecPromo" data-track-onview="eecPromo" href="https://www.jumia.co.ke/health-beauty/">
#            <div class="ar _1-1">
#             <img alt="Beauty" class="-rad4" data-lazy="" data-src="https://ke.jumia.is/cms/2022/JA22/Live/Day01/Thumbnails/Skin-Essentials.png" src="..."/>
#            </div>
#            <p class="-maxs -fs14 -elli2">
#             Beauty
#            </p>
#           </a>
#          </div>
#          <div class="itm -pvs _v">
#           <a class="-fw -rad4 -hov-e-2" data-creative="https://ke.jumia.is/cms/2022/JA22/Live/Day01/Thumbnails/feminine-feel.png" data-id="home_DTN_JA22_WomenFashion" data-name="DTN_JA22_WomenFashion" data-position="thumbnails_1_8" data-track-onclick="eecPromo" data-track-onview="eecPromo" href="https://www.jumia.co.ke/womens-fashion/">
#            <div class="ar _1-1">
#             <img alt="Women Fashion" class="-rad4" data-lazy="" data-src="https://ke.jumia.is/cms/2022/JA22/Live/Day01/Thumbnails/feminine-feel.png" src="..."/>
#            </div>
#            <p class="-maxs -fs14 -elli2">
#             Women Fashion
#            </p>
#           </a>
#          </div>
#          <div class="itm -pvs _v">
#           <a class="-fw -rad4 -hov-e-2" data-creative="https://ke.jumia.is/cms/2022/JA22/Live/Day01/Thumbnails/Every-Man.png" data-id="home_DTN_JA22_MensFashion" data-name="DTN_JA22_MensFashion" data-position="thumbnails_1_9" data-track-onclick="eecPromo" data-track-onview="eecPromo" href="https://www.jumia.co.ke/mens-fashion/">
#            <div class="ar _1-1">
#             <img alt="Mens Fashion" class="-rad4" data-lazy="" data-src="https://ke.jumia.is/cms/2022/JA22/Live/Day01/Thumbnails/Every-Man.png" src="..."/>
#            </div>
#            <p class="-maxs -fs14 -elli2">
#             Mens Fashion
#            </p>
#           </a>
#          </div>
#          <div class="itm -pvs _v">
#           <a class="-fw -rad4 -hov-e-2" data-creative="https://ke.jumia.is/cms/2022/JA22/Live/Day01/Thumbnails/baby-basics.png" data-id="home_DTN_JA22_BabyProducts" data-name="DTN_JA22_BabyProducts" data-position="thumbnails_1_10" data-track-onclick="eecPromo" data-track-onview="eecPromo" href="https://www.jumia.co.ke/baby-products/">
#            <div class="ar _1-1">
#             <img alt="Baby Products" class="-rad4" data-lazy="" data-src="https://ke.jumia.is/cms/2022/JA22/Live/Day01/Thumbnails/baby-basics.png" src="..."/>
#            </div>
#            <p class="-maxs -fs14 -elli2">
#             Baby Products
#            </p>
#           </a>
#          </div>
#          <div class="itm -pvs _v">
#           <a class="-fw -rad4 -hov-e-2" data-creative="https://ke.jumia.is/cms/2022/JA22/Live/Day01/Thumbnails/Free-Delivery-rvsd.png" data-id="home_DTN_JA22_FDY" data-name="DTN_JA22_FDY" data-position="thumbnails_1_11" data-track-onclick="eecPromo" data-track-onview="eecPromo" href="https://www.jumia.co.ke/mlp-free-delivery/">
#            <div class="ar _1-1">
#             <img alt="Free Delivery" class="-rad4" data-lazy="" data-src="https://ke.jumia.is/cms/2022/JA22/Live/Day01/Thumbnails/Free-Delivery-rvsd.png" src="..."/>
#            </div>
#            <p class="-maxs -fs14 -elli2">
#             Free Delivery
#            </p>
#           </a>
#          </div>
#         </div>
#         <button class="c-btn _prev _dis" type="button">
#          <svg class="ic" height="24" viewbox="0 0 24 24" width="24">
#           <use xlink:href="https://www.jumia.co.ke/assets_he/images/i-icons.edbc85eb.svg#arrow-left">
#           </use>
#          </svg>
#         </button>
#         <button class="c-btn _next" type="button">
#          <svg class="ic" height="24" viewbox="0 0 24 24" width="24">
#           <use xlink:href="https://www.jumia.co.ke/assets_he/images/i-icons.edbc85eb.svg#arrow-right">
#           </use>
#          </svg>
#         </button>
#        </div>
#       </section>
#      </div>
#      <div class="col16 -pvs">
#       <section class="card -oh _fw -rad4">
#        <header class="row _no-g -fw-nw -j-bet -i-ctr -phm -mh-48px" style="color:#FFFFFF;background:#e61601;">
#         <div class="cola -df -i-ctr -oh col5">
#          <svg class="ic -fsh0 -mrs" height="32" viewbox="0 0 24 24" width="32">
#           <use xlink:href="https://www.jumia.co.ke/assets_he/images/i-global.cd8c5f0c.svg#flash-sales">
#           </use>
#          </svg>
#          <h2 class="-m -fs20 -elli">
#           Flash Sales
#          </h2>
#         </div>
#         <div class="col6 -mra -fs20 -tac">
#          Time Left:
#          <time class="-b -ws-p" data-cd="" datetime="2022-06-19T10:00:00+03:00">
#           22h : 00m : 36s
#          </time>
#         </div>
#         <div class="col -df -j-end -fsh0">
#          <a class="-df -i-ctr -upp -m -mls -pvxs" href="/flash-sales/">
#           See All
#           <svg class="ic" height="24" style="fill:#FFFFFF;" viewbox="0 0 24 24" width="24">
#            <use xlink:href="https://www.jumia.co.ke/assets_he/images/i-icons.edbc85eb.svg#arrow-right">
#            </use>
#           </svg>
#          </a>
#         </div>
#        </header>
#        <div class="crs-w _main -phxs">
#         <div class="crs row _no-g -fw-nw _6cl-4cm -pvxs">
#          <div class="itm col">
#           <article class="prd _box _hvr">
#            <a class="core" data-brand="Annov" data-category="Home &amp; Office/Home &amp; Kitchen/Kitchen &amp; Dining/Small Appliances/Mixers/Hand Mixers" data-dimension23="69999" data-dimension26="" data-dimension27="" data-dimension28="0" data-dimension37="0" data-dimension43="JA22" data-dimension44="0" data-id="AN944HA0HHZYSNAFAMZ" data-list="flashsale_1" data-name="7-Speed Portable Hand Mixer With Bowl 1spoon 1 Fork" data-position="1" data-price="8.10" data-track-onclick="eecProduct" data-track-onview="eecProduct" href="/annov-7-speed-portable-hand-mixer-with-bowl-1spoon-1-fork-63239392.html">
#             <img alt="Annov 7-Speed Portable Hand Mixer With Bowl 1spoon 1 Fork" class="img" data-lazy="" data-src="https://ke.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/29/393236/1.jpg?4353" height="185" src="..." width="185"/>
#             <div class="name">
#              Annov 7-Speed Portable Hand Mixer With Bowl 1spoon 1 Fork
#             </div>
#             <div class="prc" data-oprc="KSh 1,999">
#              KSh 999
#             </div>
#             <div class="bdg _dsct">
#              50%
#             </div>
#             <div class="stk">
#              71 items left
#              <div class="meter _s" style="background-image:linear-gradient(to right,#f6b01e 71%,#c7c7cd 71%);">
#              </div>
#             </div>
#            </a>
#           </article>
#          </div>
#          <div class="itm col">
#           <article class="prd _box _hvr">
#            <a class="core" data-brand="Fashion" data-category="Fashion/Men's Fashion/Accessories/Sunglasses &amp; Eyewear Accessories/Sunglasses" data-dimension23="69999" data-dimension26="209" data-dimension27="4" data-dimension28="0" data-dimension37="0" data-dimension43="BF21_UN3|DOW_200|FS|JA22|JA22_6" data-dimension44="0" data-id="GE840FC0MJUQMNAFAMZ" data-list="flashsale_1" data-name="HD Night Vision Driving Glasses" data-position="2" data-price="1.61" data-track-onclick="eecProduct" data-track-onview="eecProduct" href="/hd-night-vision-driving-glasses-black-generic-mpg123495.html">
#             <img alt="Fashion HD Night Vision Driving Glasses" class="img" data-lazy="" data-src="https://ke.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/37/877854/1.jpg?2817" height="185" src="..." width="185"/>
#             <div class="name">
#              Fashion HD Night Vision Driving Glasses
#             </div>
#             <div class="prc" data-oprc="KSh 400">
#              KSh 199
#             </div>
#             <div class="bdg _dsct">
#              50%
#             </div>
#             <div class="stk">
#              91 items left
#              <div class="meter _s" style="background-image:linear-gradient(to right,#f6b01e 91%,#c7c7cd 91%);">
#              </div>
#             </div>
#            </a>
#           </article>
#          </div>
#          <div class="itm col">
#           <article class="prd _box _hvr">
#            <a class="core" data-brand="Fashion" data-category="Fashion/Men's Fashion/Accessories/Sunglasses &amp; Eyewear Accessories/Sunglasses" data-dimension23="69999" data-dimension26="32" data-dimension27="3.9" data-dimension28="0" data-dimension37="0" data-dimension43="JA22|JA22_6" data-dimension44="0" data-id="GE840FC117YUQNAFAMZ" data-list="flashsale_1" data-name="HD Night Vision Driving Glasses +white Cap" data-position="3" data-price="1.61" data-track-onclick="eecProduct" data-track-onview="eecProduct" href="/fashion-hd-night-vision-driving-glasses-white-cap-45571526.html">
#             <img alt="Fashion HD Night Vision Driving Glasses +white Cap" class="img" data-lazy="" data-src="https://ke.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/62/517554/1.jpg?0928" height="185" src="..." width="185"/>
#             <div class="name">
#              Fashion HD Night Vision Driving Glasses +white Cap
#             </div>
#             <div class="prc" data-oprc="KSh 680">
#              KSh 199
#             </div>
#             <div class="bdg _dsct">
#              71%
#             </div>
#             <div class="stk">
#              79 items left
#              <div class="meter _s" style="background-image:linear-gradient(to right,#f6b01e 79%,#c7c7cd 79%);">
#              </div>
#             </div>
#            </a>
#           </article>
#          </div>
#          <div class="itm col">
#           <article class="prd _box _hvr">
#            <a class="core" data-brand="Johnnie Walker" data-category="Grocery/Drinks/Beer, Wine &amp; Spirits/Spirits &amp; Liquors/Whiskey" data-dimension23="" data-dimension26="52" data-dimension27="4.7" data-dimension28="1" data-dimension37="0" data-dimension43="COL_305|CP_10|CP_11|CP_MT102|CP_MT104|CP_MT116|CP_MT36|CP_MT50|CP_MT57|CP_MT61|CP_MT84|CP_MT86|CP_MT94|DOW_102|FDYJE|GTU|INV_CLEAR|JA22|JMALL|JPRIME|UND_6|UND_7" data-dimension44="0" data-id="JO385DR1N7081NAFAMZ" data-list="flashsale_1" data-name="Song Of Ice Whiskey - Limited Edition - 1 Litre" data-position="4" data-price="15.41" data-track-onclick="eecProduct" data-track-onview="eecProduct" href="/song-of-ice-whiskey-limited-edition-1-litre-johnnie-walker-mpg351695.html">
#             <img alt="Johnnie Walker Song Of Ice Whiskey - Limited Edition - 1 Litre" class="img" data-lazy="" data-src="https://ke.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/99/424225/1.jpg?6933" height="185" src="..." width="185"/>
#             <div class="name">
#              Johnnie Walker Song Of Ice Whiskey - Limited Edition - 1 Litre
#             </div>
#             <div class="prc" data-oprc="KSh 5,300">
#              KSh 1,900
#             </div>
#             <div class="bdg _dsct">
#              64%
#             </div>
#             <div class="stk">
#              41 items left
#              <div class="meter _s" style="background-image:linear-gradient(to right,#f6b01e 82%,#c7c7cd 82%);">
#              </div>
#             </div>
#            </a>
#           </article>
#          </div>
#          <div class="itm col">
#           <article class="prd _box _hvr">
#            <a class="core" data-brand="Fresh Fri" data-category="Grocery/Food Cupboard/Cooking Oil/Vegetable Oil/Small Packs" data-dimension23="" data-dimension26="154" data-dimension27="4.6" data-dimension28="1" data-dimension37="0" data-dimension43="DOW_11|JA22|JA22_4|Merch_32|RSBVG" data-dimension44="0" data-id="FR720FF0QXUEQNAFAMZ" data-list="flashsale_1" data-name="Fresh Fri Triple Refined Vegetable Cooking Oil - 2 Litres" data-position="5" data-price="6.48" data-track-onclick="eecProduct" data-track-onview="eecProduct" href="/triple-refined-vegetable-cooking-oil-2-litres-fresh-fri-mpg337051.html">
#             <img alt="Fresh Fri Fresh Fri Triple Refined Vegetable Cooking Oil - 2 Litres" class="img" data-lazy="" data-src="https://ke.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/45/249074/1.jpg?7909" height="185" src="..." width="185"/>
# ...
#          Jumia International Shipping
#         </a>
#        </li>
#        <li>
#         <a class="_link -pbxs" href="https://www.jumia.co.ke/sp-jumia-advertising/">
#          Advertise with Jumia
#         </a>
#        </li>
#        <li>
#         <a class="_link -pbxs" href="https://www.jumia.co.ke/sp-jumia-logistics/">
#          Jumia Logistics Services
#         </a>
#        </li>
#        <li>
#         <a class="_link -pbxs" href="https://docs.google.com/forms/d/1Rwm4VKblLubA4W3xrM_GzIlhAzJVms_B2bxXGOtL8XU/">
#          Report a Product
#         </a>
#        </li>
#       </ul>
#      </div>
#      <div class="col4 -df -d-co -pvs">
#       <span class="f-t -pbm">
#        ABOUT JUMIA
#       </span>
#       <ul class="-lsn">
#        <li>
#         <a class="_link -pbxs" href="https://www.jumia.co.ke/about_new/">
#          About us
#         </a>
#        </li>
#        <li>
#         <a class="_link -pbxs" href="https://www.jumia.co.ke/careers/">
#          Jumia Careers
#         </a>
#        </li>
#        <li>
#         <a class="_link -pbxs" href="https://www.jumia.co.ke/jumia-express/">
#          Jumia Express
#         </a>
#        </li>
#        <li>
#         <a class="_link -pbxs" href="https://www.jumia.co.ke/terms-and-conditions/">
#          Terms and Conditions
#         </a>
#        </li>
#        <li>
#         <a class="_link -pbxs" href="https://www.jumia.co.ke/privacy/">
#          Privacy &amp; Cookie Notice
#         </a>
#        </li>
#        <li>
#         <a class="_link -pbxs" href="https://www.jumia.co.ke/sp-ups/">
#          UPS - Jumia International Shipping
#         </a>
#        </li>
#       </ul>
#      </div>
#      <div class="col4 -df -d-co -pvs">
#       <span class="f-t -pbm">
#        MAKE MONEY WITH JUMIA
#       </span>
#       <ul class="-lsn">
#        <li>
#         <a class="_link -pbxs" href="https://www.jumia.co.ke/market-place/">
#          Sell on Jumia
#         </a>
#        </li>
#        <li>
#         <a class="_link -pbxs" href="https://www.jumia.co.ke/jforce/">
#          Become a Sales Consultant
#         </a>
#        </li>
#        <li>
#         <a class="_link -pbxs" href="https://jumia_form.formstack.com/forms/3pl_interest_registration_en">
#          Become a Logistics Service Partner
#         </a>
#        </li>
#        <li>
#         <a class="_link -pbxs" href="https://forms.gle/WmYEPeQJbqgQD3Da8">
#          Jumia City Partner Program
#         </a>
#        </li>
#       </ul>
#      </div>
#      <div class="col4 row -c-start -pvs">
#       <span class="f-t col16 -pbm">
#        JUMIA INTERNATIONAL
#       </span>
#       <ul class="col5 -df -d-co -lsn">
#        <li>
#         <a class="_link -pbxs" href="https://www.jumia.dz/">
#          Algeria
#         </a>
#        </li>
#        <li>
#         <a class="_link -pbxs" href="https://www.jumia.ci/">
#          Ivory Coast
#         </a>
#        </li>
#        <li>
#         <a class="_link -pbxs" href="https://www.jumia.com.eg/">
#          Egypt
#         </a>
#        </li>
#        <li>
#         <a class="_link -pbxs" href="https://www.jumia.com.gh/">
#          Ghana
#         </a>
#        </li>
#        <li>
#         <a class="_link -pbxs" href="https://www.jumia.ma/">
#          Morocco
#         </a>
#        </li>
#        <li>
#         <a class="_link -pbxs" href="https://www.jumia.com.ng/">
#          Nigeria
#         </a>
#        </li>
#       </ul>
#       <ul class="col5 -df -d-co -lsn">
#        <li>
#         <a class="_link -pbxs" href="https://www.jumia.sn/">
#          Senegal
#         </a>
#        </li>
#        <li>
#         <a class="_link -pbxs" href="https://www.jumia.com.tn/">
#          Tunisia
#         </a>
#        </li>
#        <li>
#         <a class="_link -pbxs" href="https://www.jumia.ug/">
#          Uganda
#         </a>
#        </li>
#        <li>
#         <a class="_link -pbxs" href="https://www.jumia.co.za/">
#          South Africa
#         </a>
#        </li>
#        <li>
#         <a class="_link -pbxs" href="https://www.zando.co.za/">
#          Zando
#         </a>
#        </li>
#       </ul>
#      </div>
#     </div>
#     <div class="row -pbl">
#      <div class="col4 row">
#       <div class="f-t col16 -pbm">
#        JOIN US ON
#       </div>
#       <div class="col16 -phn -fs0">
#        <a class="ic-link -pas" href="https://www.facebook.com/JumiaKenya" rel="noopener" target="_blank" title="Facebook Jumia Kenya">
#         <svg class="ic" height="26" viewbox="0 0 24 24" width="26">
#          <use xlink:href="https://www.jumia.co.ke/assets_he/images/i-icons.edbc85eb.svg#soc-facebook">
#          </use>
#         </svg>
#        </a>
#        <a class="ic-link -pas" href="https://www.instagram.com/jumiakenya/" rel="noopener" target="_blank" title="Instagram Jumia Kenya">
#         <svg class="ic" height="26" viewbox="0 0 24 24" width="26">
#          <use xlink:href="https://www.jumia.co.ke/assets_he/images/i-icons.edbc85eb.svg#soc-instagram">
#          </use>
#         </svg>
#        </a>
#        <a class="ic-link -pas" href="https://twitter.com/JumiaKenya" rel="noopener" target="_blank" title="Twitter Jumia Kenya">
#        </a>
#        <a class="ic-link -pas" href="https://www.youtube.com/user/KenyaJumia" rel="noopener" target="_blank" title="YouTube Jumia Kenya">
#         <svg class="ic" height="26" viewbox="0 0 24 24" width="26">
#          <use xlink:href="https://www.jumia.co.ke/assets_he/images/i-icons.edbc85eb.svg#soc-youtube">
#          </use>
#         </svg>
#        </a>
#       </div>
#      </div>
#      <div class="col12 row">
#       <div class="f-t col16 -pbm">
#        PAYMENT METHODS
#       </div>
#       <div class="col16 -phn -df -fw-w">
#        <a class="ic-link -pas" href="https://www.jumia.co.ke/payment/" title="Payment on delivery">
#         <svg class="ic" height="24" viewbox="0 0 24 24" width="24">
#          <use xlink:href="https://www.jumia.co.ke/assets_he/images/i-global.cd8c5f0c.svg#pay-cashondelivery">
#          </use>
#         </svg>
#        </a>
#        <a class="ic-link -pas" href="https://www.jumia.co.ke/payment/" title="Visa">
#         <svg class="ic" height="24" viewbox="0 0 31 24" width="31">
#          <use xlink:href="https://www.jumia.co.ke/assets_he/images/i-global.cd8c5f0c.svg#pay-visa">
#          </use>
#         </svg>
#        </a>
#        <a class="ic-link -pas" href="https://www.jumia.co.ke/payment/" title="Mastercard">
#         <svg class="ic" height="24" viewbox="0 0 36 24" width="36">
#          <use xlink:href="https://www.jumia.co.ke/assets_he/images/i-global.cd8c5f0c.svg#pay-mastercard">
#          </use>
#         </svg>
#        </a>
#        <a class="ic-link -pas" href="https://www.jumia.co.ke/jumiapay/" title="Jumia Pay">
#         <svg class="ic" height="24" viewbox="0 0 85 24" width="85">
#          <use xlink:href="https://www.jumia.co.ke/assets_he/images/i-global.cd8c5f0c.svg#pay-jumiapay">
#          </use>
#         </svg>
#        </a>
#       </div>
#      </div>
#     </div>
#     <div class="row -pbl">
#      <ul class="col2 -df -d-co -lsn">
#       <li>
#        <a class="_link -pbxs" href="/14-hands/">
#         14 Hands
#        </a>
#       </li>
#       <li>
#        <a class="_link -pbxs" href="/adidas/">
#         Adidas
#        </a>
#       </li>
#      </ul>
#      <ul class="col2 -df -d-co -lsn">
#       <li>
#        <a class="_link -pbxs" href="/haier/">
#         Haier
#        </a>
#       </li>
#       <li>
#        <a class="_link -pbxs" href="/hp/">
#         HP
#        </a>
#       </li>
#      </ul>
#      <ul class="col2 -df -d-co -lsn">
#       <li>
#        <a class="_link -pbxs" href="/lenovo/">
#         Lenovo
#        </a>
#       </li>
#       <li>
#        <a class="_link -pbxs" href="/nike/">
#         Nike
#        </a>
#       </li>
#      </ul>
#      <ul class="col2 -df -d-co -lsn">
#       <li>
#        <a class="_link -pbxs" href="/nivea/">
#         NIVEA
#        </a>
#       </li>
#       <li>
#        <a class="_link -pbxs" href="/panasonic/">
#         Panasonic
#        </a>
#       </li>
#      </ul>
#      <ul class="col2 -df -d-co -lsn">
#       <li>
#        <a class="_link -pbxs" href="/sandisk/">
#         Sandisk
#        </a>
#       </li>
#       <li>
#        <a class="_link -pbxs" href="/skyworth/">
#         Skyworth
#        </a>
#       </li>
#      </ul>
#      <ul class="col2 -df -d-co -lsn">
#       <li>
#        <a class="_link -pbxs" href="/sony/">
#         Sony
#        </a>
#       </li>
#       <li>
#        <a class="_link -pbxs" href="/syinix/">
#         Syinix
#        </a>
#       </li>
#      </ul>
#      <ul class="col2 -df -d-co -lsn">
#       <li>
#        <a class="_link -pbxs" href="/tagwood/">
#         TAGWOOD
#        </a>
#       </li>
#       <li>
#        <a class="_link -pbxs" href="/ulefone/">
#         Ulefone
#        </a>
#       </li>
#      </ul>
#      <ul class="col2 -df -d-co -lsn">
#       <li>
#        <a class="_link -pbxs" href="/vision-plus/">
#         Vision Plus
#        </a>
#       </li>
#       <li>
#        <a class="_link -pbxs" href="/xiaomi/">
#         XIAOMI
#        </a>
#       </li>
#      </ul>
#     </div>
#     <div class="vb row -i-ctr -j-ctr _foot _gy7 -hr -gy3 -mtl">
#      <div class="col3 -df -j-start">
#      </div>
#      <div class="col10 -df -j-ctr -fs0">
#       <a class="vent-link" href="https://www.jumia.co.ke/mlp-jumia-prime/" rel="nofollow noopener" target="_blank" title="Jumia Prime">
#        <svg class="ic" height="24" viewbox="0 0 77 24" width="77">
#         <use xlink:href="https://www.jumia.co.ke/assets_he/images/i-global.cd8c5f0c.svg#venture-prime">
#         </use>
#        </svg>
#       </a>
#       <a class="vent-link" href="https://food.jumia.co.ke/drinks/k0zt/jumia-party" rel="nofollow noopener" target="_blank" title="Jumia Party">
#       </a>
#       <a class="vent-link" href="https://pay.jumia.co.ke/?utm_source=jumia&amp;utm_medium=mall&amp;utm_campaign=Venturebar" rel="nofollow noopener" target="_blank" title="Jumia Pay">
#        <svg class="ic" height="24" viewbox="0 0 60 24" width="60">
#         <use xlink:href="https://www.jumia.co.ke/assets_he/images/i-global.cd8c5f0c.svg#venture-pay">
#         </use>
#        </svg>
#       </a>
#       <a class="vent-link" href="https://www.jumia.co.ke/sp-jumia-logistics/?utm_source=jumia&amp;utm_medium=mall&amp;utm_campaign=Venturebar" rel="nofollow noopener" target="_blank" title="Jumia Logistic Services">
#        <svg class="ic" height="24" viewbox="0 0 108 24" width="108">
#         <use xlink:href="https://www.jumia.co.ke/assets_he/images/i-global.cd8c5f0c.svg#venture-logistics">
#         </use>
#        </svg>
#       </a>
#      </div>
#      <div class="col3 -df -j-end -wt -mla">
#      </div>
#     </div>
#    </footer>
#    <div class="banner-pop" data-bnrid="108" data-end="2022-06-30T12:00:00+03:00">
#     <a class="-fw -fh" data-creative="https://ke.jumia.is/cms/2022/W20/KE_JA22_Authentication_0622_PU.jpg" data-id="home_DPU_Login" data-name="DPU_Login" data-position="banner_normal" data-set-cookie="/mlp-anniversary/?source=DPU_Login" data-track-onclick="eecPromo" data-track-onview="eecPromo" href="/mlp-anniversary/?source=DPU_Login">
#      <img alt="DPU_Login" class="-fw -fh" data-lazy="" data-src="https://ke.jumia.is/cms/2022/W20/KE_JA22_Authentication_0622_PU.jpg" src="..."/>
#     </a>
#     <button aria-label="Close banner" class="cls">
#      <span class="ic-bg -bg-wt">
#       <svg class="ic -maxs" height="16" viewbox="0 0 24 24" width="16">
#        <use xlink:href="https://www.jumia.co.ke/assets_he/images/i-icons.edbc85eb.svg#close">
#        </use>
#       </svg>
#      </span>
#     </button>
#    </div>
#    <div id="pop">
#     <div aria-hidden="false" aria-label="newsletter_popup_close-cta" aria-modal="true" class="popup _open _l" data-pop="" data-pop-id="newsletter" role="dialog">
#      <section aria-labelledby="pop-ttl" class="cw">
#       <button aria-label="newsletter_popup_close-cta" class="cls">
#        <svg class="ic" height="24" viewbox="0 0 24 24" width="24">
#         <use xlink:href="https://www.jumia.co.ke/assets_he/images/i-icons.edbc85eb.svg#close">
#         </use>
#        </svg>
#       </button>
#       <h2 class="ttl -vh-sr" id="pop-ttl">
#        Welcome to Jumia!
#       </h2>
#       <div class="cont _nl">
#        <div class="-df">
#         <div class="-fsh0" style="width:265px;background:url('https://ke.jumia.is/cms/2021/W15/CP/Banners/KE_Cross_0421_PU.jpg') top/cover no-repeat;">
#         </div>
#         <div class="-paxl -tac -fw">
#          <h2 class="-fs29 -phl">
#           Welcome to Jumia!
#          </h2>
#          <div class="-ptl">
#           <p class="-fs16 -m -pbxs">
#            Subscribe to our newsletter
#           </p>
#           and be the first one to know about our amazing deals
#          </div>
#          <form action="/newsletter/subscription/default/" class="nl-form _pop -ptl -tal" data-eventaction="Subscribed" data-eventcategory="Newsletter Popup" data-track-onnlsuccess="" id="nl-pop-f" method="post">
#           <div class="nl-fi-w -mbxs">
#            <label class="nl-lbl -vh-sr" for="fi-nl-pop-email">
#             E-mail
#            </label>
#            <input class="nl-fi" id="fi-nl-pop-email" name="email" placeholder="Enter E-mail Address" required="" type="email" value=""/>
#            <svg class="ic -f-gy3" height="18" viewbox="0 0 24 24" width="18">
#             <use xlink:href="https://www.jumia.co.ke/assets_he/images/i-icons.edbc85eb.svg#email">
#             </use>
#            </svg>
#           </div>
#           <div class="-df -ptxs">
#            <button class="nl-btn btn _prim _md -fw" name="gender" value="male">
#             Male
#            </button>
#            <button class="nl-btn btn _prim _md -fw" name="gender" value="female">
#             Female
#            </button>
#           </div>
#           <input name="csrfToken" type="hidden" value="00f7b1a48044f5c3a8fd7fde9e52e838"/>
#          </form>
#         </div>
#        </div>
#       </div>
#      </section>
#     </div>
#    </div>
#   </div>
#   <script>
#    var dataLayer=[{"countryCode":"KE","language":"en","platform":"desktop","url":"/","pageType":"home","pageKey":"home","pageTitle":"Jumia Kenya | Online Shopping for Groceries, Appliances, Cleaning Supplies & more","abTests":"CLP:A#SearchPerso:Y#Cart:E","joinedPageType":"home"}];(function(w,d,s,l,i,f){function go(){w[l]=w[l]||[];w[l].push({"gtm.start":new Date().getTime(),event:"gtm.js"});f=d.getElementsByTagName(s)[0],j=d.createElement(s),dl=l!="dataLayer"?"&l="+l:"";j.async=true;j.src="//www.googletagmanager.com/gtm.js?id="+i+dl;j.addEventListener('load',function(){dataLayer.push({event:'pageView'});(function(){setTimeout((function(){window.dataLayer.push({event:"pageViewLvl2"}),setTimeout((function(){window.dataLayer.push({event:"pageViewLvl3"})}),500)}),500)})()});f.parentNode.insertBefore(j,f);}w.addEventListener("load",go,false);})(window,document,'script','dataLayer','GTM-KS6DC65');
#   </script>
#   <script>
#    window.__STORE__={"view":"Home","activeLanguage":"en","countryCode":"KE","languages":{"en":{"text":"English","default":true}},"svgFallback":false,"tracking":{"gtm":{"key":"GTM-KS6DC65","url":"/","pageType":"home","pageKey":"home"}},"csrfToken":"00f7b1a48044f5c3a8fd7fde9e52e838","user":{"id":""},"sprites":{"icons":"https://www.jumia.co.ke/assets_he/images/i-icons.edbc85eb.svg","global":"https://www.jumia.co.ke/assets_he/images/i-global.cd8c5f0c.svg","shop":"https://www.jumia.co.ke/assets_he/images/i-jumia.svg"},"liveChat":{"loadingText":"Live Chat is loading...","botImg":"https://www.jumia.co.ke/assets_he/images/bot.5beef7d8.svg"},"timeLabels":{"w":"w","d":"d","h":"h","m":"m","s":"s"},"htmlErrors":{"valueMissing":"Required field","typeMismatch":"Invalid Information","patternMismatch":"Invalid Information"},"popups":{"newsletter":{"data":{"title":"Welcome to Jumia!","closeCTA":"newsletter_popup_close-cta"},"trackingData":{"viewPopup":{"type":"Newsletter"},"closePopup":{"type":"Newsletter"}},"template":"Default","shouldOpen":true,"size":"L","hideTitle":true}}};
#   </script>
#   <script crossorigin="" src="https://www.jumia.co.ke/assets_he/js/common.328201ae.js" type="module">
#   </script>
#   <script crossorigin="" src="https://www.jumia.co.ke/assets_he/js/pages/home/index.a5ec34f2.js" type="module">
#   </script>
#   <script nomodule="" src="https://www.jumia.co.ke/assets_he/js/common.es5.dad092a5.js">
#   </script>
#   <script nomodule="" src="https://www.jumia.co.ke/assets_he/js/pages/home/index.es5.6ecdd0c8.js">
#   </script>
#  </body>
# </html>
